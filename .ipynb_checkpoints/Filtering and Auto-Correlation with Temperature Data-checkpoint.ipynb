# %%
import numpy as np
import pandas as pd
from pandas.plotting import autocorrelation_plot, lag_plot
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib inline

# %% [markdown]
# # Before start, let's review gridspec (https://matplotlib.org/users/gridspec.html)

# %%
def make_ticklabels_invisible(fig):
    for i, ax in enumerate(fig.axes):
        ax.text(0.5, 0.5, "ax%d" % (i+1), va="center", ha="center")
        for tl in ax.get_xticklabels() + ax.get_yticklabels():
            tl.set_visible(False)
gs = gridspec.GridSpec(3, 3)
ax1 = plt.subplot(gs[0, :])
ax2 = plt.subplot(gs[1, :-1])
ax3 = plt.subplot(gs[1:, -1])
ax4 = plt.subplot(gs[-1, 0])
ax5 = plt.subplot(gs[-1, -2])

plt.suptitle("GridSpec")
make_ticklabels_invisible(plt.gcf())

# %%
#%% load data that will be used in the script
CityTable     = pd.read_csv('input/city_attributes.csv')
TemperatureDF = pd.read_csv('input/temperature.csv', index_col=0)
TemperatureDF.index = pd.to_datetime(TemperatureDF.index)
TemperatureDFH =  9/5* (TemperatureDF- 273) + 32

# %% [markdown]
# ## List of Cities

# %%
CityTable.head()
# Out:
#             City        Country   Latitude   Longitude
# 0      Vancouver         Canada  49.249660 -123.119339
# 1       Portland  United States  45.523449 -122.676208
# 2  San Francisco  United States  37.774929 -122.419418
# 3        Seattle  United States  47.606209 -122.332069
# 4    Los Angeles  United States  34.052231 -118.243683

# %% [markdown]
# ## Time Variation of Temperatures for Selected Cities

# %%
citiesToShow  = ['Dallas','Houston', 'Miami','Montreal']

# %%
TemperatureDFH.tail()
# Out:
#                      Vancouver  Portland  San Francisco  Seattle  Los Angeles  \
# datetime
# 2017-11-29 20:00:00        NaN    48.200            NaN   46.076       68.990
# 2017-11-29 21:00:00        NaN    49.802            NaN   47.570       72.824
# 2017-11-29 22:00:00        NaN    50.702            NaN   49.550       73.328
# 2017-11-29 23:00:00        NaN    50.036            NaN   49.928       72.770
# 2017-11-30 00:00:00        NaN    48.704            NaN   50.072       71.474
#
#                      San Diego  Las Vegas  Phoenix  Albuquerque  Denver  \
# datetime
# 2017-11-29 20:00:00     66.470     61.772   71.078       54.896  61.808
# 2017-11-29 21:00:00     67.532     63.698   72.662       56.210  63.860
# 2017-11-29 22:00:00     67.244     65.012   73.850       56.192  62.078
# 2017-11-29 23:00:00     67.298     66.470   75.470       55.652  61.106
# 2017-11-30 00:00:00     65.120     65.552   75.470       53.060  53.924
#
#                        ...      Philadelphia  New York  Montreal  Boston  \
# datetime               ...
# 2017-11-29 20:00:00    ...            63.032       NaN    35.834  59.144
# 2017-11-29 21:00:00    ...            61.232       NaN    34.034  55.436
# 2017-11-29 22:00:00    ...            56.804       NaN    32.864  51.692
# 2017-11-29 23:00:00    ...            52.826       NaN    31.064  48.506
# 2017-11-30 00:00:00    ...            50.756       NaN    29.840  45.770
#
#                      Beersheba  Tel Aviv District  Eilat  Haifa  Nahariyya  \
# datetime
# 2017-11-29 20:00:00        NaN                NaN    NaN    NaN        NaN
# 2017-11-29 21:00:00        NaN                NaN    NaN    NaN        NaN
# 2017-11-29 22:00:00        NaN                NaN    NaN    NaN        NaN
# 2017-11-29 23:00:00        NaN                NaN    NaN    NaN        NaN
# 2017-11-30 00:00:00        NaN                NaN    NaN    NaN        NaN
#
#                      Jerusalem
# datetime
# 2017-11-29 20:00:00        NaN
# 2017-11-29 21:00:00        NaN
# 2017-11-29 22:00:00        NaN
# 2017-11-29 23:00:00        NaN
# 2017-11-30 00:00:00        NaN
#
# [5 rows x 36 columns]

# %%
t0 = TemperatureDF.index
t1 = pd.date_range(pd.to_datetime('1/1/2015',dayfirst=True),pd.to_datetime('30/11/2017',dayfirst=True),freq='H')
t2 = pd.date_range(pd.to_datetime('1/1/2015',dayfirst=True),pd.to_datetime('30/12/2015' ,dayfirst=True),freq='H')
t3 = pd.date_range(pd.to_datetime('1/1/2015',dayfirst=True),pd.to_datetime('30/6/2015',dayfirst=True),freq='H')
t4 = pd.date_range(pd.to_datetime('1/1/2015',dayfirst=True),pd.to_datetime('30/1/2015',dayfirst=True),freq='H')
timeRange = [t0, t1, t2, t3, t4]

# %% [markdown]
# ###  Temperature change for 6 years, , 2 years , 1 year, 6 month, and 1 month.

# %%
fig, ax = plt.subplots(nrows=5,ncols=1,figsize=(15,14))
for i, t in enumerate(timeRange):
    for k in range(len(citiesToShow)):
        ax[i].plot(t,TemperatureDFH.loc[t,citiesToShow[k]])

ax[0].legend(citiesToShow, fontsize=16,
              loc='upper left',bbox_to_anchor=(0.02,1.3), ncol=len(citiesToShow))
for i in range(len(ax)): ax[i].set_ylabel('Temperature [$^\circ$F]', fontsize=11)
ax[3].set_xlabel('time', fontsize=14);

# %% [markdown]
# ## Auto-Correlation function of Houston Temperature Signal

# %%
cityToShow = 'Houston'
selectedLagPoints = [1,3,6,9,12,24,36,48,60]
maxLagDays = 7

originalSignal = TemperatureDFH[cityToShow]

# %%
# set grid spec of the subplots
plt.figure(figsize=(12,6))
gs = gridspec.GridSpec(2, len(selectedLagPoints))

axTopRow = plt.subplot(gs[0, :])
axBottomRow = []
for i in range(len(selectedLagPoints)):
    axBottomRow.append(plt.subplot(gs[1, i]))
    
# plot autocorr
allTimeLags = np.arange(1,maxLagDays*24)
autoCorr = [originalSignal.autocorr(lag=dt) for dt in allTimeLags]
axTopRow.plot(allTimeLags,autoCorr); 
axTopRow.set_title('Autocorrelation Plot of Temperature Signal', fontsize=18);
axTopRow.set_xlabel('time lag [hours]'); axTopRow.set_ylabel('correlation coefficient')
selectedAutoCorr = [originalSignal.autocorr(lag=dt) for dt in selectedLagPoints]
axTopRow.scatter(x=selectedLagPoints, y=selectedAutoCorr, s=50, c='r')

# plot scatter plot of selected points
for i in range(len(selectedLagPoints)):
    lag_plot(originalSignal, lag=selectedLagPoints[i], s=0.5, alpha=0.7, ax=axBottomRow[i])    
    if i >= 1:
        axBottomRow[i].set_yticks([],[])
plt.tight_layout()

# %% [markdown]
# ## Auto-Correlation with various zoom ins (temporal scales)

# %%
fig, ax = plt.subplots(nrows=4,ncols=1, figsize=(14,14))

timeLags = np.arange(1,24*24*30)  # 2 years auto correlation 
autoCorr = [originalSignal.autocorr(lag=dt) for dt in timeLags]
ax[0].plot(1.0/(24*30)*timeLags, autoCorr); ax[0].set_title('Autocorrelation Plot', fontsize=20);
ax[0].set_xlabel('time lag [months]'); ax[0].set_ylabel('correlation coeff', fontsize=12);

timeLags = np.arange(1,20*24*7) # 20 weeks
autoCorr = [originalSignal.autocorr(lag=dt) for dt in timeLags]
ax[1].plot(1.0/(24*7)*timeLags, autoCorr);
ax[1].set_xlabel('time lag [weeks]'); ax[1].set_ylabel('correlation coeff', fontsize=12);

timeLags = np.arange(1,20*24) # 20 days
autoCorr = [originalSignal.autocorr(lag=dt) for dt in timeLags]
ax[2].plot(1.0/24*timeLags, autoCorr);
ax[2].set_xlabel('time lag [days]'); ax[2].set_ylabel('correlation coeff', fontsize=12);

timeLags = np.arange(1,3*24) # 3 days
autoCorr = [originalSignal.autocorr(lag=dt) for dt in timeLags]
ax[3].plot(timeLags, autoCorr);
ax[3].set_xlabel('time lag [hours]'); ax[3].set_ylabel('correlation coeff', fontsize=12);

# %% [markdown]
# ## Moving average and the Low Pass Filtered Signal
# The output singal contains only low frequency changes.
# Applying the moving average operation (or different phrasing of the same this: filtering/convolving with a rectangular filter), is eqivalent to filtering out the high frequency changes and keeping only low frequency changes in the original signal as sugguested in the name "low pass".

# %%
#%% apply rolling mean and plot the signal (low pass filter)
windowSize = 5*24

lowPassFilteredSignal = originalSignal.rolling(windowSize, center=True).mean()

t0 = TemperatureDFH.index
t1 = pd.date_range(pd.to_datetime('1/1/2015',dayfirst=True),pd.to_datetime('30/11/2017',dayfirst=True),freq='H')
t2 = pd.date_range(pd.to_datetime('1/1/2015',dayfirst=True),pd.to_datetime('30/12/2015' ,dayfirst=True),freq='H')
t3 = pd.date_range(pd.to_datetime('1/1/2015',dayfirst=True),pd.to_datetime('30/6/2015',dayfirst=True),freq='H')
t4 = pd.date_range(pd.to_datetime('1/1/2015',dayfirst=True),pd.to_datetime('30/1/2015',dayfirst=True),freq='H')
timeRange = [t0, t1, t2, t3, t4]

# %%
originalSignal.head()
t0
# Out:
# DatetimeIndex(['2012-10-01 12:00:00', '2012-10-01 13:00:00',
#                '2012-10-01 14:00:00', '2012-10-01 15:00:00',
#                '2012-10-01 16:00:00', '2012-10-01 17:00:00',
#                '2012-10-01 18:00:00', '2012-10-01 19:00:00',
#                '2012-10-01 20:00:00', '2012-10-01 21:00:00',
#                ...
#                '2017-11-29 15:00:00', '2017-11-29 16:00:00',
#                '2017-11-29 17:00:00', '2017-11-29 18:00:00',
#                '2017-11-29 19:00:00', '2017-11-29 20:00:00',
#                '2017-11-29 21:00:00', '2017-11-29 22:00:00',
#                '2017-11-29 23:00:00', '2017-11-30 00:00:00'],
#               dtype='datetime64[ns]', name='datetime', length=45253, freq=None)

# %%
fig, ax = plt.subplots(nrows=5,ncols=1,figsize=(14,12))
ax[0].plot(t0,originalSignal,c='y')
ax[0].plot(t0,lowPassFilteredSignal,c='r')

ax[1].plot(t1,originalSignal[t1],c='y')
ax[1].plot(t1,lowPassFilteredSignal[t1],c='r')

ax[2].plot(t2,originalSignal[t2],c='y')
ax[2].plot(t2,lowPassFilteredSignal[t2],c='r')

ax[3].plot(t3,originalSignal[t3],c='y')
ax[3].plot(t3,lowPassFilteredSignal[t3],c='r')

ax[4].plot(t4,originalSignal[t4],c='y')
ax[4].plot(t4,lowPassFilteredSignal[t4],c='r')

ax[0].legend(['original signal','low pass filtered'], fontsize=18,
              loc='upper left',bbox_to_anchor=(0.02,1.4), ncol=len(citiesToShow))
for i in range(len(ax)): ax[i].set_ylabel('Temperature [$^\circ$F]', fontsize=11)
ax[4].set_xlabel('Time', fontsize=14);

# %% [markdown]
# ## High-Pass-Filtered Signal
#
# This is achieved by subtract the Low-Pass-Filtered Signal from the Original Signal.

# %%
#%% subtract the low pass filtered singal from the original to get high pass filtered signal
highPassFilteredSignal = originalSignal - lowPassFilteredSignal

fig, ax = plt.subplots(nrows=5,ncols=1,figsize=(14,12))
ax[0].plot(t0,highPassFilteredSignal,c='k')
ax[1].plot(t1,highPassFilteredSignal[t1],c='k')
ax[2].plot(t2,highPassFilteredSignal[t2],c='k')
ax[3].plot(t3,highPassFilteredSignal[t3],c='k')
ax[4].plot(t4,highPassFilteredSignal[t4],c='k')

ax[0].set_title('Deflection of Temperature from local mean',fontsize=20)
for i in range(len(ax)): ax[i].set_ylabel('$\Delta$ Temperature [$^\circ$F]', fontsize=11)
ax[4].set_xlabel('Time', fontsize=14);

# %% [markdown]
# ## Auto-Correlation of the Low Pass Filtered Signal

# %%
fig, ax = plt.subplots(nrows=4,ncols=1,figsize=(14,14))

timeLags = np.arange(1,24*24*30)
autoCorr = [lowPassFilteredSignal.autocorr(lag=dt) for dt in timeLags]
ax[0].plot(1.0/(24*30)*timeLags, autoCorr); 
ax[0].set_title('Autocorrelation Plot of Low Pass Filtered Signal', fontsize=20);
ax[0].set_xlabel('time lag [months]'); ax[0].set_ylabel('correlation coeff', fontsize=12);

timeLags = np.arange(1,20*24*7)
autoCorr = [lowPassFilteredSignal.autocorr(lag=dt) for dt in timeLags]
ax[1].plot(1.0/(24*7)*timeLags, autoCorr);
ax[1].set_xlabel('time lag [weeks]'); ax[1].set_ylabel('correlation coeff', fontsize=12);

timeLags = np.arange(1,20*24)
autoCorr = [lowPassFilteredSignal.autocorr(lag=dt) for dt in timeLags]
ax[2].plot(1.0/24*timeLags, autoCorr);
ax[2].set_xlabel('time lag [days]'); ax[2].set_ylabel('correlation coeff', fontsize=12);

timeLags = np.arange(1,3*24)
autoCorr = [lowPassFilteredSignal.autocorr(lag=dt) for dt in timeLags]
ax[3].plot(timeLags, autoCorr);
ax[3].set_xlabel('time lag [hours]'); ax[3].set_ylabel('correlation coeff', fontsize=12);

# %% [markdown]
# ## Auto-Correlation of the High Pass Filtered Signal
# Now the auto correlation of high frequency

# %%
#%% autocorr of high pass filtered signal
fig, ax = plt.subplots(nrows=4,ncols=1, figsize=(14,14))

timeLags = np.arange(1,25*24*30)
autoCorr = [highPassFilteredSignal.autocorr(lag=dt) for dt in timeLags]
ax[0].plot(1.0/(24*30)*timeLags, autoCorr); 
ax[0].set_title('Autocorrelation Plot of High Pass Filtered Signal', fontsize=20);
ax[0].set_xlabel('time lag [months]'); ax[0].set_ylabel('correlation coeff', fontsize=12);

timeLags = np.arange(1,20*24*7)
autoCorr = [highPassFilteredSignal.autocorr(lag=dt) for dt in timeLags]
ax[1].plot(1.0/(24*7)*timeLags, autoCorr);
ax[1].set_xlabel('time lag [weeks]'); ax[1].set_ylabel('correlation coeff', fontsize=12);

timeLags = np.arange(1,20*24)
autoCorr = [highPassFilteredSignal.autocorr(lag=dt) for dt in timeLags]
ax[2].plot(1.0/24*timeLags, autoCorr);
ax[2].set_xlabel('time lag [days]'); ax[2].set_ylabel('correlation coeff', fontsize=12);

timeLags = np.arange(1,3*24)
autoCorr = [highPassFilteredSignal.autocorr(lag=dt) for dt in timeLags]
ax[3].plot(timeLags, autoCorr);
ax[3].set_xlabel('time lag [hours]'); ax[3].set_ylabel('correlation coeff', fontsize=12);
